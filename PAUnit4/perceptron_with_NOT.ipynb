# %% [markdown]
# # Perceptron Logic Gates Implementation
#
# This notebook implements various logic gates using the perceptron model with a step activation function. It demonstrates how simple neural network principles can be used to model fundamental Boolean logic operations.
#
# ## Overview
# - **Imports**: NumPy for numerical operations and a custom `step` function from utilities
# - **Gate Implementations**: Functions that model logic gates (starting with NOT gate)
# - **Testing**: Verification of gate outputs with truth tables
#
# The perceptron uses weights and bias terms to learn and compute logical operations through the step activation function.

# %%
import numpy as np
from utils import step

# %%
def NOT(x1):
    weights = -1
    bias = 1
    output = np.dot([1], weights) + bias
    
    return step(output)

# %%
print('NOT Gate')
for x in [0,1]:
    print(x, '->', NOT(x))
